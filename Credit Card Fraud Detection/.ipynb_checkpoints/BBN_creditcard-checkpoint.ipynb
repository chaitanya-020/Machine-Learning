# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import RandomOverSampler 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from pgmpy.models import BayesianModel
from pgmpy.estimators import HillClimbSearch, MaximumLikelihoodEstimator
from pgmpy.estimators import BayesianEstimator
from pgmpy.inference import VariableElimination
from hmmlearn.hmm import GaussianHMM
from sklearn.metrics import classification_report

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.drop('Time',inplace=True,axis=1)

# %%
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
remove=df.iloc[:,10:28]
remove
# Out:
#              V11       V12       V13       V14       V15       V16       V17  \
# 0      -0.551600 -0.617801 -0.991390 -0.311169  1.468177 -0.470401  0.207971
# 1       1.612727  1.065235  0.489095 -0.143772  0.635558  0.463917 -0.114805
# 2       0.624501  0.066084  0.717293 -0.165946  2.345865 -2.890083  1.109969
# 3      -0.226487  0.178228  0.507757 -0.287924 -0.631418 -1.059647 -0.684093
# 4      -0.822843  0.538196  1.345852 -1.119670  0.175121 -0.451449 -0.237033
# ...          ...       ...       ...       ...       ...       ...       ...
# 284802 -1.593105  2.711941 -0.689256  4.626942 -0.924459  1.107641  1.991691
# 284803 -0.150189  0.915802  1.214756 -0.675143  1.164931 -0.711757 -0.025693
# 284804  0.411614  0.063119 -0.183699 -0.510602  1.329284  0.140716  0.313502
# 284805 -1.933849 -0.962886 -1.042082  0.449624  1.962563 -0.608577  0.509928
# 284806 -1.040458 -0.031513 -0.188093 -0.084316  0.041333 -0.302620 -0.660377
#
# ...

# %%
df=df.drop(remove,axis=1)
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  Amount  Class
# 0       0.239599  0.098698  0.363787  0.090794  149.62      0
# ...

# %%
correlation_matrix = df.corr()

# %%
correlation_matrix
# Out:
#                   V1            V2            V3            V4            V5  \
# V1      1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16  1.812612e-17
# V2      4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15  5.157519e-16
# V3     -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16 -6.539009e-17
# V4     -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00 -1.719944e-15
# V5      1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15  1.000000e+00
# V6     -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16  2.408382e-16
# V7     -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16  2.715541e-16
# V8     -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16  7.437229e-16
# V9     -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16  7.391702e-16
# V10     7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16 -5.202306e-16
# Amount -2.277087e-01 -5.314089e-01 -2.108805e-01  9.873167e-02 -3.863563e-01
# ...

# %%
fig = plt.subplots(figsize=(15,15)) 
sns.heatmap(correlation_matrix, vmax= 1 )
# Out:
# <AxesSubplot:>

# %%
subset = df.sample(n=10000, random_state=42)

# %%
subset
# Out:
#                V1        V2         V3        V4         V5        V6  \
# 43428  -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 49906    0.339812 -2.743745  -0.134070 -1.385729  -1.451413  1.015887
# 29474    1.399590 -0.590701   0.168619 -1.029950  -0.539806  0.040444
# 276481  -0.432071  1.647895  -1.669361 -0.349504   0.785785 -0.630647
# 278846   2.014160 -0.137394  -1.015839  0.327269  -0.182179 -0.956571
# ...           ...       ...        ...       ...        ...       ...
# 240378  -0.954519  0.992190  -0.847651 -1.581983   0.715487  0.307996
# 111987   1.622073 -0.865882  -0.538933 -1.524359  -0.799222 -0.894892
# 210990  -1.482246 -0.517592   1.187354 -3.104914  -0.827490 -0.198460
# 97524   -0.615090  1.354411   0.580766 -0.094208   0.114572 -0.570746
# 98359   -0.476832  1.001665   1.672802 -0.004422  -0.053953 -0.619122
#
#                V7        V8        V9        V10  Amount  Class
# ...

# %%
X_subset = subset.drop('Class', axis=1)
y_subset = subset['Class']

# %%
variable_mapping = {i: col for i, col in enumerate(X_subset.columns)}
renamed_X_subset = X_subset.rename(columns=variable_mapping)

# %%
X_subset.rename(columns={'Class': 'Class_node'}, inplace=True)

# %%
renamed_X_subset
# Out:
#                V1        V2         V3        V4         V5        V6  \
# 43428  -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 49906    0.339812 -2.743745  -0.134070 -1.385729  -1.451413  1.015887
# 29474    1.399590 -0.590701   0.168619 -1.029950  -0.539806  0.040444
# 276481  -0.432071  1.647895  -1.669361 -0.349504   0.785785 -0.630647
# 278846   2.014160 -0.137394  -1.015839  0.327269  -0.182179 -0.956571
# ...           ...       ...        ...       ...        ...       ...
# 240378  -0.954519  0.992190  -0.847651 -1.581983   0.715487  0.307996
# 111987   1.622073 -0.865882  -0.538933 -1.524359  -0.799222 -0.894892
# 210990  -1.482246 -0.517592   1.187354 -3.104914  -0.827490 -0.198460
# 97524   -0.615090  1.354411   0.580766 -0.094208   0.114572 -0.570746
# 98359   -0.476832  1.001665   1.672802 -0.004422  -0.053953 -0.619122
#
#                V7        V8        V9        V10  Amount
# 43428  -16.701694  7.517344 -8.507059 -14.110184  364.19
# ...

# %%
col=list(subset.columns)
col
# Out:
# ['V1',
#  'V2',
#  'V3',
#  'V4',
#  'V5',
#  'V6',
#  'V7',
#  'V8',
#  'V9',
#  'V10',
#  'Amount',
#  'Class']

# %%
len(col)
# Out:
# 12

# %%
bbn_model = BayesianModel()
for i in range(len(col)-1):
    bbn_model.add_edge(col[i],col[i+1])

# %%
bbn_model.nodes()
# Out:
# NodeView(('V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'Amount', 'Class'))

# %%
bbn_model.fit(subset, estimator=BayesianEstimator)

# %%
bbn_inference = VariableElimination(bbn_model)

# %%
# elimination_order = [ 'V2', 'V3','V4','V5','V6','V7','V8','V9','V10']

# %%
# query = bbn_inference.query(variables=['Class'], evidence=X_subset.iloc[0].to_dict())

# %%
# query.values

# %%
y_pred = []
for index, instance in X_subset.iterrows():
    query = bbn_inference.map_query(variables=['Class'], evidence=instance.to_dict())
    y_pred.append(query.values)
# Out:
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Finding Elimination Order: : : 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# ...

# %%
y_pred
